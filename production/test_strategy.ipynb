# %%
from strategy1 import Strategy
# Out:
# 2024-02-01 18:46:50.878335: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-01 18:46:51.788146: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-01 18:46:51.788260: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-01 18:46:51.836219: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-01 18:46:52.148700: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
st = Strategy(
    pair="BTCUSDT",
    heartbeat_url="",
    heartbeat_period=300,
    testnet=True,
    verbose=True
)

# %%
#14999.88
st.start_trading(
    interval="1h",
    initial_lev=50,
    num_candles=500,
)
# Out:
# /home/mauricio/.pyenv/versions/3.10.7/envs/bot/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /home/mauricio/.pyenv/versions/3.10.7/envs/bot/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /home/mauricio/.pyenv/versions/3.10.7/envs/bot/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# .CURRENTLY_NEUTRAL NO STOP MARKET
# ...

# %%
st.stop_trading(
    go_neutral = False
)
# Out:
# CLOSE frame received, closing websocket connection

# %%
st.data
# Out:
#                         Open     High      Low    Close    Volume  \
# Date
# 2024-01-11 07:00:00  46444.9  47189.9  46194.0  46550.0  4179.627
# 2024-01-11 08:00:00  46373.3  46590.0  46115.0  46494.4  4478.899
# 2024-01-11 09:00:00  46461.4  46800.0  46150.0  46259.4  4328.711
# 2024-01-11 10:00:00  46364.8  47000.0  46150.0  46859.0  4400.029
# 2024-01-11 11:00:00  46850.1  47189.9  46700.0  47041.9  4633.066
# ...                      ...      ...      ...      ...       ...
# 2024-02-01 00:00:00  42646.0  43119.5  42646.0  42895.9  3519.934
# 2024-02-01 01:00:00  42895.9  43116.0  42300.0  42308.0  4097.243
# 2024-02-01 02:00:00  41969.9  42171.0  41940.0  42146.6  8880.423
# 2024-02-01 03:00:00  42146.5  42177.4  41947.0  41998.0  6557.943
# 2024-02-01 04:00:00  41998.0  42053.9  41961.0  42003.5  2880.277
#
#                      Quote Asset Volume  Number of Trades  \
# Date
# 2024-01-11 07:00:00        1.947196e+08            2781.0
# ...

# %%
st.data.index
# Out:
# DatetimeIndex(['2024-01-11 04:00:00', '2024-01-11 05:00:00',
#                '2024-01-11 06:00:00', '2024-01-11 07:00:00',
#                '2024-01-11 08:00:00', '2024-01-11 09:00:00',
#                '2024-01-11 10:00:00', '2024-01-11 11:00:00',
#                '2024-01-11 12:00:00', '2024-01-11 13:00:00',
#                ...
#                '2024-01-31 15:00:00', '2024-01-31 16:00:00',
#                '2024-01-31 17:00:00', '2024-01-31 18:00:00',
#                '2024-01-31 19:00:00', '2024-01-31 20:00:00',
#                '2024-01-31 21:00:00', '2024-01-31 22:00:00',
#                '2024-01-31 23:00:00', '2024-02-01 00:00:00'],
#               dtype='datetime64[ns]', name='Date', length=501, freq=None)

# %%
st.go_short(
        order_type = "LIMIT",
        price=41000,
        quote=200,
        use_wallet_prc = False,
        reduceOnly = False,
    )
st.go_stop_market(
    when_prc_reaches=99.0,
    cancel_previous=True
)
# Out:
# ENTRY: 42700.0
# LIQ:  3030438.43431873
# STOP: 3000561.0
# ---------------------------------------------------------------------------
# BinanceAPIException                       Traceback (most recent call last)
# Cell In[3], line 8
#       1 st.go_short(
#       2         order_type = "LIMIT",
#       3         price=41000,
#    (...)
#       6         reduceOnly = False,
#       7     )
# ----> 8 st.go_stop_market(
#       9     when_prc_reaches=99.0,
#      10     cancel_previous=True
#      11 )
#
# File ~/Desktop/trading-bot/production/futures_trader.py:492, in FuturesTrader.go_stop_market(self, when_prc_reaches, cancel_previous)
#     490 print("LIQ: ", str(liq_price))
#     491 print("STOP:", str(stopPrice))
# --> 492 self.client.futures_create_order(
#     493     stopPrice=stopPrice,
#     494     quantity=base,
#     495     symbol=self.pair,
#     496     side=side.value,
#     497     type="STOP_MARKET",
#     498     reduceOnly=True
#     499 )
#
# ...

# %%
st.client.futures_position_information(
                symbol=st.pair
            )[0]["liquidationPrice"]
# Out:
# '3030438.43431873'

# %%
from helpers import binance_run

for i in range(5):
    binance_run(
        function=st.go_short,
        order_type = "LIMIT",
        price=45000,
        quote=200,
        use_wallet_prc = False,
        reduceOnly = False,
    )

# %%
from helpers import binance_run
from strategy1 import Strategy

st = Strategy(
        pair="BTCUSDT",
        heartbeat_url="",
        heartbeat_period=300,
        testnet=True,
        verbose=True
    )

binance_run(
    function=st.cancel_all_open_orders
)
binance_run(
    function=st.go_short,
    order_type = "LIMIT",
    price=45000,
    quote=200,
    use_wallet_prc = False,
    reduceOnly = False,
)

# %%
for i in range(5):
    binance_run(
        function=st.cancel_all_open_orders
    )
